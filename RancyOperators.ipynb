# %% [markdown]
# <center> <span style="color:#ff42a4; font-weight:bold">ARITHMETIC OPERATIONS</span> </center>

# %%
a=18
b=38
print ("Addition: ", a+b)
# Out:
# Addition:  56

# %%
print("Subtraction: ", a-b)
print("Subtraction: ", b-a)
# Out:
# Subtraction:  -20
# Subtraction:  20

# %%
print("multiplication: ", a*b)
# Out:
# multiplication:  684

# %%
print("division: ", a/b)
print("division: ", b/a)
# Out:
# division:  0.47368421052631576
# division:  2.111111111111111

# %%
print("Floor Division: ", a//b)
print("Floor Division: ", b//a)
# Out:
# Floor Division:  0
# Floor Division:  2

# %%
print("Modulus or Remainder: ", b%a)
# Out:
# Modulus or Remainder:  2

# %%
#a to the power to b is done with Exponential operator **
print("Exponential: ", a**b)
# Out:
# Exponential:  501597304410594428739556550045321223614364647424

# %% [markdown]
# Mathematical follow precedence model called PEDMAS P-Parenthis, E-Exponential, D-Division, M-Multiplication, A-Addition, s-Subtraction

# %%
print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
a = 4 + (8 ** 2) - 3 ** 2 % 1 
print(a)
# Out:
# 68

# %% [markdown]
# <center> <span style="color:#ff42a4; font-weight:bold">STRING OPERATIONS</span> </center>

# %%
#string operator is immutable type which means it cannot be changed
#string can be defined with both " and '
# to use ' in  a string then define it with " or use \'
#\n is for new line
print("Hey, how are you")
print("Hey \'We should be focused\'")
print("text in line 1 \n text in line 2")
# Out:
# Hey, how are you
# Hey 'We should be focused'
# text in line 1
#  text in line 2

# %% [markdown]
# <b>String Concatenation</b>

# %%
#use +  to concatenate string
flavor=input("What flavor do you like: ")
dessert=input("Which desert would you like to have: ")
print("Great choice! let me get you: ",flavor+' '+dessert)
# Out:
# What flavor do you like: Chocolate
# Which desert would you like to have: Pastry
# Great choice! let me get you:  Chocolate Pastry

# %% [markdown]
# ##String Manipulations
#
# ##### Indexing in Strings
# <ul>
#     <li>Forward indexing starts wiht 0</li>
#     <li>Reverse indexing starts with last character as -1 in string</li>
#     <li>Strings are immutable, which means they cannot be changed once created</li>
#     <li>Strings can be modified by slicing a part of it and concatenating with another</li>
# <ul>

# %%
#Len function to find length of the string
string="I have not failed, I've just found 10,000 ways that won't work - Thomas A.Edison"
len(string)
# Out:
# 80

# %%
#Accessing first character also known as forward indexing
string[0]
# Out:
# 'I'

# %%
string[79]
# Out:
# 'n'

# %%
#Accessing last character using negative indexing
string[-1]
# Out:
# 'n'

# %%
string[-3]
# Out:
# 's'

# %%
#test immutability of string
string[2]='t'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-be731a34733e> in <module>
#       1 #test immutability of string
# ----> 2 string[2]='t'
#
# TypeError: 'str' object does not support item assignment

# %%
string="I have not failed, I've just found 10,000 ways that won't work - Einstein"
print(string)
# Out:
# I have not failed, I've just found 10,000 ways that won't work - Einstein

# %% [markdown]
# <b>Slicing in Strings</b>
# <li>string[start:End:step]</li>

# %%
slice_state = string[0:64]
print(slice_state)
# Out:
# I have not failed, I've just found 10,000 ways that won't work -

# %%
batch ="5 girls 3 boys in class"
#first 8 characters
print(batch[:8])
# Out:
# 5 girls

# %%
#extract remaining characters
print(batch[8:])
# Out:
# 3 boys in class

# %%
# check string is in the string also called as membership
string1 = "Did you attend Data Science Class"
print('Machine' in string1)
# Out:
# False

# %%
print('Science' in string1)
# Out:
# True

# %%
word="I love Python programming"
print(word[-18:-12])
# Out:
# Python

# %%
x = 'len'
x[len(x * 2) - 5]
# Out:
# 'e'

# %%
x*2
# Out:
# 'lenlen'

# %% [markdown]
# <b>String methods</b>
# <ul><li>upper()</li><li>lower()</li><li>strip()</li><li>count(substring,begin,end)</li></ul>

# %%
small="i am lower case"
small.upper()
# Out:
# 'I AM LOWER CASE'

# %%
upper = "I AM UPPER case"
upper.lower()
# Out:
# 'i am upper case'

# %%
some_sentence='There is space at end    '
print(some_sentence.rstrip())
# Out:
# There is space at end

# %%
someother = "   There is space in front"
print(someother.lstrip())
# Out:
# There is space in front

# %%
someanother ="There is space at stadium    sss"
print(someanother.rstrip('s'))
# Out:
# There is space at stadium

# %%
string2 = "*****texthere#####"
print(string2.lstrip('*').rstrip('#'))
# Out:
# texthere

# %%
#count a character in a string
string3="count how many o"
string3.count('o')
# Out:
# 3

# %%
string3.count('o',2) #second parameter is starting index
# Out:
# 2

# %%
#using format() method to print
A="Data"
B="Analysis"
C="Panda"
print ("{0} {1} using {2}".format(A,B,C))
# Out:
# Data Analysis using Panda

# %%
help(str) #string operations help
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

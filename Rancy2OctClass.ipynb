# %%
print("Welcome to Python Programming")
# Out:
# Welcome to Python Programming

# %%
print("we are printing")
# Out:
# we are printing

# %%
print("one more time printing")
# Out:
# one more time printing

# %%
#language : vocab + grammar
#Programming: Keyword + Syntax

# %%
print("something")

# %%
print("nothing")
print('ssomethin's wrong')
# Out:
#   File "<ipython-input-6-adb8853eb8d0>", line 2
#     print('ssomethin's wrong')
#                      ^
# SyntaxError: invalid syntax

# %%
myname=input()
print("hello", myname)

# %%
print("hey")
# Out:
# hey

# %%
kg = int(input('Enter weight: '))
grams = kg*1000
print("The weight in grams is ",grams)

# %%
principal = int(input('Enter principal amount: '))
InterestRate = int(input('Enter Interest Rate amount: '))
Time = int(input('Enter Time: '))
SimpleInterest = principal * InterestRate * Time/100
print("Interest Rate is: ", int(SimpleInterest))

# %%
principal = int(input('Enter principal amount: '))
InterestRate = int(input('Enter Interest Rate amount: '))
Time = int(input('Enter Time: '))
SimpleInterest = principal * InterestRate * Time/100
print("Interest Rate is: ", int(SimpleInterest))
# Out:
# Enter principal amount: 1
# Enter Interest Rate amount: 1
# Enter Time: 1
# Interest Rate is:  0

# %%
p = int(input('enter principle '))
r = int(input('enter rate. '))
t = int(input('enter time '))

si = (p*r*t)/100

print("""

Principle {p}
Rate      {r}
Time      {t}

Simple Interest is {si}
""")
# Out:
# enter principle 20
# enter rate. 10
# enter time 10
#
#
# Principle {p}
# Rate      {r}
# Time      {t}
#
# Simple Interest is {si}

# %%
p = int(input('enter principle '))
r = int(input('enter rate. '))
t = int(input('enter time '))

si = (p*r*t)/100

print(f"""

Principle {p}
Rate      {r}
Time      {t}

Simple Interest is {si}
""")
# Out:
# enter principle 20
# enter rate. 10
# enter time 10
#
#
# Principle 20
# Rate      10
# Time      10
#
# Simple Interest is 20.0

# %%
"I am here"
# Out:
# 'I am here'

# %%
""" I am here
But who else is"""
# Out:
# ' I am here\nBut who else is'

# %%
print(""" I am here
But who else is""")
# Out:
#  I am here
# But who else is

# %%
'a'
'b'
'c'
# Out:
# 'c'

# %%
number = int(input("Enter a number: "))
if number>0:
    print("positive number")
else:
    if number<0:
        print("negative number")
    else:
         print("neutral number")
# Out:
# Enter a number: 2
# positive number

# %%
age = int(input("Please input your age: "))
if age>=18:
    print("Yay! you are eligible to vote")
else:
    print("sorry, you are not eligible yet, you still have few years before you can vote")
# Out:
# Please input your age: 20
# Yay! you can vote

# %%
number = int(input("Enter a number: "))
if number>0:
    print("positive number")
elif number<0:
    print("negative number")
else:
    print("neutral number")
# Out:
# Enter a number: 0
# neutral number

# %%
number = int(input("Enter a number: "))
if number>0:
    "positive number"
elif number<0:
    "negative number"
else:
    "neutral number"
# Out:
# Enter a number: 0

# %%
meter =5
while meter<=50:
    print(meter)
    meter=meter+5
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
meter=1
while meter<=10:
    print(meter*5)
    meter=meter+1
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %% [markdown]
# This is markdown cell
# <font color = red>Does this appear red </font>

# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %% [markdown]
# M what is markdown

# %%
print("=" * 10)

# %%
name = input("What is your name:")
print("Greetings of the day: ", name)
print("{name} have a great day ahead")
# Out:
# What is your name:Rancy
# Greetings of the day:  Rancy
# {name} have a great day ahead

# %%
name = input("What is your name:")
print("Greetings of the day: ", name)
print(f"{name} have a great day ahead")
# Out:
# What is your name:Rancy
# Greetings of the day:  Rancy
# Rancy have a great day ahead

# %%
age = input("Enter your age: ")
print("Your age in months is: ", age*12)
# Out:
# Enter your age: 38
# Your age in months is:  383838383838383838383838

# %%
age = int(input("Enter your age: "))
print("Your age in months is: ", age*12)
# Out:
# Enter your age: 38
# Your age in months is:  456

# %%
string = "some string"
boolean = False
integ = 22
float1 = 2.3
type(string)
type(boolean)
type(integ)
type(float1)
# Out:
# float

# %%
string = "some string"
boolean = False
integ = 22
float1 = 2.3

# %%
type(string)
# Out:
# str

# %%
type(boolean)
# Out:
# bool

# %%
type(integ)
# Out:
# int

# %%
type(float1)
# Out:
# float

# %%
x=3.45
str(x)
# Out:
# '3.45'

# %%
int(x)
# Out:
# 3

# %%
float(x)
# Out:
# 3.45

# %%
bool(x)
# Out:
# True

# %%
name= rancy
print(type(name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-0250bbf1de5a> in <module>
# ----> 1 name= rancy
#       2 print(type(name))
#
# NameError: name 'rancy' is not defined
